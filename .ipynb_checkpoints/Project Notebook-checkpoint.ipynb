# %% [markdown]
# Website:
# https://jesparza17.github.io/Jesparza17/

# %% [markdown]
# # Spin to Win? An Analysis of Which Pitchers Were Hurt the Most After MLB's Crackdown on Sticky Stuff
# ### By: Julian Esparza and Sam Broth

# %% [markdown]
# ### Background

# %% [markdown]
# The two of us are working together on our final tutorial project. We would like to analyze data about baseball, specifically about pitchers, to attempt to conclude which pitchers may have been using illegal “sticky stuff” prior to the crackdown on it by Major League Baseball. Three rules in the [MLB’s very detailed rulebook](https://img.mlbstatic.com/mlb-images/image/upload/mlb/atcjzj9j7wrgvsm8wnjq.pdf "2021 MLB Rulebook") essentially prohibit the application of “foreign substances” directly on the baseball. While these rules have been there for a long time, they were very rarely enforced. One anonymous former pitcher estimated that prior to June 2021, [an overwhelming majority of pitchers in the MLB used some substance(s)](https://www.si.com/mlb/2021/06/04/sticky-stuff-is-the-new-steroids-daily-cover "'This Should Be the Biggest Scandal in Sports'") to help them alter the movement and spin on their pitches. These substances range anywhere from sunscreen to glue. It always seemed that everyone accepted how the MLB and its umpires turned a blind eye to this - that is, until a few months ago. On June 21, 2021, commissioner Rob Manfred and Major League Baseball finally [decided to enforce the rules](https://www.espn.com/mlb/story/_/id/31682815/major-league-baseball-crackdown-sticky-substances-begins-regular-checks-pitchers-monday "Major League Baseball's crackdown on sticky substances begins with regular checks on pitchers Monday") and crackdown on sticky stuff. After all, the league-wide batting average was the [lowest it had been since 1968](https://www.espn.com/mlb/story/_/id/31371552/mlb-hopes-offensive-numbers-perk-historically-rough-april-hitters "MLB hopes offensive numbers perk up after historically rough April for hitters")!
# Using data from multiple sources, we hope to see which pitchers were negatively affected from this change. The dataset we are most excited about working with is from [Baseball Savant](https://baseballsavant.mlb.com/ "Baseball Savant"), a really great website for all things [sabermetrics](https://en.wikipedia.org/wiki/Sabermetrics "Sabermetrics"). There is a plethora of statistics we can use, and we are happy to explore all of them. A few that will really come in handy - average spin and average break by pitch.

# %% [markdown]
# ### Questions We Would Like to Answer
# * Which pitchers’ average spin rate dropped the most after the enforcement of the rule?
#
# * Which pitchers’ expected batting average got higher after the change?
#
# * Did some pitchers stop throwing a favorite pitch of theirs because they were better at it before the change?
#
# * Is velocity affected by change in spin rate?
#
#
# While we can most likely get most of our answers from the amazing datasets on Baseball Savant, [FanGraphs](https://www.fangraphs.com/ "FanGraphs") may also come in handy with more historical data.

# %% [markdown]
# ### Collaboration Plan
# Our collaboration plan revolves around our shared GitHub repository, which will be where everything is easily accessible. We meet, mostly on Zoom, as often as required, and perhaps use VSCode if we need to be coding at the same time. We have both found that its LiveShare feature works very well for that.

# %% [markdown]
# ### Data ETL
#
# #### Extraction

# %%
##Importing Necessary Packages
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# The datasets shown below were extracted from [Baseball Savant](https://baseballsavant.mlb.com/leaderboard/active-spin "Active Spin Leaderboard"). In this website we are given many datasets which can be filtered based upon several different options in a drop down menu. This menu allows for data to be broken down by a certain statistic across players in the MLB.

# %% [markdown]
# ## Load and Transform

# %%
#Loading first data frame from csv of actice spin of pitchers in 2021
spin_2020 = pd.read_csv("active-spin 2020.csv")

#Getting rid of rows we will not be using(what hand pithcer uses)
spin_2020 = spin_2020.drop(spin_2020.columns[2], axis = 1)

#Creating new column combining first and last name for ease
spin_2020['Name'] = spin_2020[' first_name'] + ' ' + spin_2020['last_name']

#Getting rid of previous name columns
spin_2020 = spin_2020.drop(spin_2020.columns[:2], axis = 1)

#Moving new name column to first column
position = spin_2020.pop("Name")
spin_2020.insert(0,'Name',position)
spin_2020
# Out:
#                   Name  active_spin_fourseam  active_spin_sinker  \
# 0         Tejay Antone                   NaN                85.4
# 1            Alex Cobb                   NaN                97.3
# 2         Brady Singer                   NaN                87.2
# 3           Ryan Weber                   NaN                93.2
# 4       Ryan Yarbrough                   NaN                97.6
# ..                 ...                   ...                 ...
# 144         Mike Minor                  66.6                 NaN
# 145        Brad Keller                  65.3                73.3
# 146     Framber Valdez                  63.9                70.4
# 147   Spencer Turnbull                  61.0                75.4
# 148   Garrett Richards                  58.9                63.1
#
#      active_spin_cutter  active_spin_changeup  active_spin_fastball  \
# 0                   NaN                  98.9                   NaN
# 1                   NaN                   NaN                   NaN
# 2                   NaN                  97.1                   NaN
# 3                  43.4                  96.2                   NaN
# 4                  43.1                  94.8                   NaN
# ..                  ...                   ...                   ...
# 144                 NaN                  95.8                   NaN
# 145                 NaN                  77.7                   NaN
# 146                 NaN                  76.1                   NaN
# 147                 NaN                  92.8                   NaN
# 148                 NaN                   NaN                   NaN
#
#      active_spin_slider  active_spin_curve
# 0                  41.0               81.0
# 1                   NaN               65.7
# 2                  34.7                NaN
# 3                   NaN               82.6
# 4                   NaN               78.3
# ..                  ...                ...
# 144                24.9               72.3
# 145                45.3                NaN
# 146                 NaN               76.5
# 147                35.2               81.7
# 148                28.4               89.5
#
# [149 rows x 8 columns]

# %%
#Loading first data frame from csv of actice spin of pitchers in 2021
spin_2021 = pd.read_csv("active-spin 2021.csv")

#Getting rid of rows we will not be using(what hand pithcer uses)
spin_2021 = spin_2021.drop(spin_2021.columns[2], axis = 1)

#Creating new column combining first and last name for ease
spin_2021['Name'] = spin_2021[' first_name'] + ' ' + spin_2021['last_name']

#Getting rid of previous name columns
spin_2021 = spin_2021.drop(spin_2021.columns[:2], axis = 1)

#Moving new name column to first column
position = spin_2021.pop("Name")
spin_2021.insert(0,'Name',position)
spin_2021
# Out:
#                      Name  active_spin_fourseam  active_spin_sinker  \
# 0     Lance McCullers Jr.                   NaN                75.1
# 1             Zach Davies                   NaN                98.6
# 2            Aaron Bummer                   NaN                83.1
# 3           Kyle Finnegan                   NaN                98.8
# 4            Wander Suero                   NaN                 NaN
# ..                    ...                   ...                 ...
# 474        Marcus Stroman                  62.1                58.7
# 475          Austin Adams                  59.7                 NaN
# 476      Spencer Turnbull                  59.5                78.2
# 477         Dillon Maples                  52.5                55.5
# 478      Garrett Richards                  49.7                62.0
#
#      active_spin_cutter  active_spin_changeup  active_spin_fastball  \
# 0                  26.0                  94.1                   NaN
# 1                  78.0                  96.9                   NaN
# 2                  16.5                   NaN                   NaN
# 3                   NaN                   NaN                   NaN
# 4                  60.0                  69.4                   NaN
# ..                  ...                   ...                   ...
# 474                28.9                   NaN                   NaN
# 475                 NaN                   NaN                   NaN
# 476                53.1                  93.5                   NaN
# 477                 NaN                   NaN                   NaN
# 478                 NaN                  86.3                   NaN
#
#      active_spin_slider  active_spin_curve
# 0                  43.2               70.3
# 1                   NaN               66.0
# 2                  82.1                NaN
# 3                  46.8                NaN
# 4                   NaN               71.2
# ..                  ...                ...
# 474                52.9               71.6
# 475                37.1                NaN
# 476                34.7               80.6
# 477                53.3               80.2
# 478                28.4               93.7
#
# [479 rows x 8 columns]

# %%
break_2020 = pd.read_csv("pitch_movement 2020.csv")
break_2020 = break_2020.drop(break_2020.columns[3:9], axis =1)
break_2020 = break_2020.drop(break_2020.columns[3:8], axis =1)
#Creating new column combining first and last name for ease
break_2020['Name'] = break_2020[' first_name'] + ' ' + break_2020['last_name']

#Getting rid of previous name columns
break_2020 = break_2020.drop(break_2020.columns[1:3], axis = 1)

#Moving new name column to first column
position = break_2020.pop("Name")
break_2020.insert(0,'Name',position)
break_2020
# Out:
#                   Name  year  pitcher_break_z  league_break_z  diff_z  rise  \
# 0           Lance Lynn  2020             15.4           -15.2    -0.2    -1
# 1          Gerrit Cole  2020             11.5           -13.7     2.1    16
# 2    Antonio Senzatela  2020             20.0           -14.9    -5.1   -34
# 3        Andrew Heaney  2020             17.1           -17.1    -0.1     0
# 4        Lucas Giolito  2020             12.5           -13.9     1.4    10
# 5         Brady Singer  2020             19.2           -21.5    -2.3   -11
# 6       Framber Valdez  2020             25.8           -21.8     4.0    18
# 7      Cristian Javier  2020             14.1           -16.5     2.4    14
# 8        Chris Paddack  2020             14.7           -14.1    -0.6    -4
# 9         Max Scherzer  2020             15.0           -15.1     0.2     1
# 10      Dinelson Lamet  2020             34.4           -34.1     0.2     1
# 11        Trevor Bauer  2020             11.7           -15.5     3.8    24
# 12         Austin Voth  2020             15.7           -16.1     0.4     3
# 13        Matthew Boyd  2020             18.3           -16.3    -2.1   -13
# 14       Tyler Glasnow  2020             11.8           -12.7     0.9     7
# 15         Luke Weaver  2020             12.7           -15.3     2.6    17
# 16         Dylan Cease  2020             13.0           -12.7    -0.3    -2
# 17        Jacob deGrom  2020             11.4           -12.8     1.4    11
# 18          Kris Bubic  2020             16.3           -16.3     0.0     0
# 19          Robbie Ray  2020             14.2           -14.8     0.6     4
#
#     pitcher_break_x  league_break_x  diff_x  tail  percent_rank_diff_z  \
# 0               6.7            -7.6    -0.9   -12             0.487745
# 1              12.2            -8.0     4.2    53             0.906863
# 2               5.9            -7.4    -1.5   -21             0.034314
# 3              13.8            -8.6     5.2    60             0.509804
# 4               7.1            -6.5     0.6     8             0.794118
# 5              13.7           -14.6    -0.9    -6             0.241245
# 6              12.6           -14.8    -2.2   -15             0.910506
# 7               7.0            -8.0    -1.1   -13             0.936275
# 8               9.8            -6.7     3.1    46             0.414216
# 9              10.5            -8.0     2.5    31             0.573529
# 10              4.3             3.8     0.5    14             0.523810
# 11              9.6            -7.6     2.0    27             1.000000
# 12              6.2            -7.2    -1.0   -14             0.610294
# 13             11.2            -7.1     4.1    58             0.196078
# 14              0.6            -5.0    -4.4   -87             0.696078
# 15              7.4            -7.6    -0.2    -3             0.960784
# 16              4.4            -7.3    -2.9   -40             0.473039
# 17              6.9            -8.4    -1.5   -17             0.794118
# 18              6.0            -6.8    -0.8   -11             0.536765
# 19              9.6            -7.0     2.6    37             0.644608
#
#     percent_rank_diff_x
# 0              0.323529
# 1              0.924020
# 2              0.245098
# 3              0.960784
# 4              0.556373
# 5              0.284047
# 6              0.124514
# 7              0.294118
# 8              0.840686
# 9              0.776961
# 10             0.574405
# 11             0.725490
# 12             0.306373
# 13             0.916667
# 14             0.068627
# 15             0.438725
# 16             0.139706
# 17             0.245098
# 18             0.348039
# 19             0.786765

# %%
break_2021 = pd.read_csv("pitch_movement 2021.csv")
break_2021 = break_2021.drop(break_2021.columns[3:9], axis =1)
break_2021 = break_2021.drop(break_2021.columns[3:8], axis =1)
#Creating new column combining first and last name for ease
break_2021['Name'] = break_2021[' first_name'] + ' ' + break_2021['last_name']

#Getting rid of previous name columns
break_2021 = break_2021.drop(break_2021.columns[1:3], axis = 1)

#Moving new name column to first column
position = break_2021.pop("Name")
break_2021.insert(0,'Name',position)
break_2021
# Out:
#                    Name  year  pitcher_break_z  league_break_z  diff_z  rise  \
# 0            Robbie Ray  2021             13.5           -14.1     0.6     5
# 1           Sean Manaea  2021             20.1           -21.8    -1.8    -8
# 2           Tyler Mahle  2021             13.9           -15.1     1.2     8
# 3         Kevin Gausman  2021             14.2           -14.2     0.0     0
# 4             J.A. Happ  2021             16.1           -16.0     0.0     0
# ..                  ...   ...              ...             ...     ...   ...
# 388        Héctor Neris  2021             38.1           -34.8     3.3    10
# 389         Tyler Mahle  2021             28.4           -32.6    -4.2   -13
# 390   Hunter Strickland  2021             16.5           -14.4    -2.1   -15
# 391     J.P. Feyereisen  2021             10.9           -14.7     3.8    26
# 392       Brett de Geus  2021             24.7           -22.7     2.0     9
#
#      pitcher_break_x  league_break_x  diff_x  tail  percent_rank_diff_z  \
# 0                8.2            -7.1     1.1    15             0.650831
# 1               13.8           -14.4    -0.6    -4             0.278689
# 2               12.1            -7.7     4.4    57             0.776722
# 3               10.4            -7.1     3.3    47             0.527316
# 4                7.9            -6.7     1.2    18             0.527316
# ..               ...             ...     ...   ...                  ...
# 388              8.3           -10.8    -2.5   -23             0.941176
# 389             14.5           -11.2     3.4    30             0.000000
# 390              3.4            -7.3    -3.8   -53             0.149644
# 391              5.4            -6.6    -1.2   -18             0.992874
# 392             16.1           -15.0     1.0     7             0.750000
#
#      percent_rank_diff_x
# 0               0.612827
# 1               0.327869
# 2               0.923990
# 3               0.845606
# 4               0.624703
# ..                   ...
# 388             0.176471
# 389             1.000000
# 390             0.104513
# 391             0.330166
# 392             0.639344
#
# [393 rows x 12 columns]

# %%
#Merged Spin rate of 2020 and break of 2020 for a data set that contained all necessary info for 2020
year2020 = spin_2020.merge(break_2020, on = ['Name'], how = 'outer')
year2020
# Out:
#                   Name  active_spin_fourseam  active_spin_sinker  \
# 0         Tejay Antone                   NaN                85.4
# 1            Alex Cobb                   NaN                97.3
# 2         Brady Singer                   NaN                87.2
# 3           Ryan Weber                   NaN                93.2
# 4       Ryan Yarbrough                   NaN                97.6
# ..                 ...                   ...                 ...
# 144         Mike Minor                  66.6                 NaN
# 145        Brad Keller                  65.3                73.3
# 146     Framber Valdez                  63.9                70.4
# 147   Spencer Turnbull                  61.0                75.4
# 148   Garrett Richards                  58.9                63.1
#
#      active_spin_cutter  active_spin_changeup  active_spin_fastball  \
# 0                   NaN                  98.9                   NaN
# 1                   NaN                   NaN                   NaN
# 2                   NaN                  97.1                   NaN
# 3                  43.4                  96.2                   NaN
# 4                  43.1                  94.8                   NaN
# ..                  ...                   ...                   ...
# 144                 NaN                  95.8                   NaN
# 145                 NaN                  77.7                   NaN
# 146                 NaN                  76.1                   NaN
# 147                 NaN                  92.8                   NaN
# 148                 NaN                   NaN                   NaN
#
#      active_spin_slider  active_spin_curve    year  pitcher_break_z  \
# 0                  41.0               81.0     NaN              NaN
# 1                   NaN               65.7     NaN              NaN
# 2                  34.7                NaN  2020.0             19.2
# 3                   NaN               82.6     NaN              NaN
# 4                   NaN               78.3     NaN              NaN
# ..                  ...                ...     ...              ...
# 144                24.9               72.3     NaN              NaN
# 145                45.3                NaN     NaN              NaN
# 146                 NaN               76.5  2020.0             25.8
# 147                35.2               81.7     NaN              NaN
# 148                28.4               89.5     NaN              NaN
#
#      league_break_z  diff_z  rise  pitcher_break_x  league_break_x  diff_x  \
# 0               NaN     NaN   NaN              NaN             NaN     NaN
# 1               NaN     NaN   NaN              NaN             NaN     NaN
# 2             -21.5    -2.3 -11.0             13.7           -14.6    -0.9
# 3               NaN     NaN   NaN              NaN             NaN     NaN
# 4               NaN     NaN   NaN              NaN             NaN     NaN
# ..              ...     ...   ...              ...             ...     ...
# 144             NaN     NaN   NaN              NaN             NaN     NaN
# 145             NaN     NaN   NaN              NaN             NaN     NaN
# 146           -21.8     4.0  18.0             12.6           -14.8    -2.2
# 147             NaN     NaN   NaN              NaN             NaN     NaN
# 148             NaN     NaN   NaN              NaN             NaN     NaN
#
#      tail  percent_rank_diff_z  percent_rank_diff_x
# 0     NaN                  NaN                  NaN
# 1     NaN                  NaN                  NaN
# 2    -6.0             0.241245             0.284047
# 3     NaN                  NaN                  NaN
# 4     NaN                  NaN                  NaN
# ..    ...                  ...                  ...
# 144   NaN                  NaN                  NaN
# 145   NaN                  NaN                  NaN
# 146 -15.0             0.910506             0.124514
# 147   NaN                  NaN                  NaN
# 148   NaN                  NaN                  NaN
#
# [149 rows x 19 columns]

# %%
#Merged Spin rate of 2021 and break of 2021 for a data set that contained all necessary info for 2021
year2021 = spin_2021.merge(break_2021, on = ['Name'], how = 'outer')
year2021
# Out:
#                      Name  active_spin_fourseam  active_spin_sinker  \
# 0     Lance McCullers Jr.                   NaN                75.1
# 1     Lance McCullers Jr.                   NaN                75.1
# 2     Lance McCullers Jr.                   NaN                75.1
# 3             Zach Davies                   NaN                98.6
# 4             Zach Davies                   NaN                98.6
# ..                    ...                   ...                 ...
# 601          Austin Adams                  59.7                 NaN
# 602      Spencer Turnbull                  59.5                78.2
# 603         Dillon Maples                  52.5                55.5
# 604      Garrett Richards                  49.7                62.0
# 605      Garrett Richards                  49.7                62.0
#
#      active_spin_cutter  active_spin_changeup  active_spin_fastball  \
# 0                  26.0                  94.1                   NaN
# 1                  26.0                  94.1                   NaN
# 2                  26.0                  94.1                   NaN
# 3                  78.0                  96.9                   NaN
# 4                  78.0                  96.9                   NaN
# ..                  ...                   ...                   ...
# 601                 NaN                   NaN                   NaN
# 602                53.1                  93.5                   NaN
# 603                 NaN                   NaN                   NaN
# 604                 NaN                  86.3                   NaN
# 605                 NaN                  86.3                   NaN
#
#      active_spin_slider  active_spin_curve    year  pitcher_break_z  \
# 0                  43.2               70.3  2021.0             24.9
# 1                  43.2               70.3  2021.0             32.5
# 2                  43.2               70.3  2021.0             49.2
# 3                   NaN               66.0  2021.0             22.6
# 4                   NaN               66.0  2021.0             36.5
# ..                  ...                ...     ...              ...
# 601                37.1                NaN  2021.0             35.3
# 602                34.7               80.6     NaN              NaN
# 603                53.3               80.2     NaN              NaN
# 604                28.4               93.7  2021.0             22.0
# 605                28.4               93.7  2021.0             37.3
#
#      league_break_z  diff_z  rise  pitcher_break_x  league_break_x  diff_x  \
# 0             -22.8     2.1   9.0             13.7           -15.2    -1.5
# 1             -35.4    -2.9  -8.0             13.7             6.8     6.9
# 2             -46.0     3.2   7.0             11.9             9.6     2.3
# 3             -25.1    -2.5 -10.0             14.5           -14.3     0.1
# 4             -36.8    -0.3  -1.0             13.7           -14.2    -0.5
# ..              ...     ...   ...              ...             ...     ...
# 601           -34.2     1.2   3.0             10.0             5.6     4.3
# 602             NaN     NaN   NaN              NaN             NaN     NaN
# 603             NaN     NaN   NaN              NaN             NaN     NaN
# 604           -15.1    -6.9 -45.0              1.3            -7.7    -9.0
# 605           -32.4     5.0  15.0              3.1             3.7    -0.6
#
#       tail  percent_rank_diff_z  percent_rank_diff_x
# 0    -10.0             0.762295             0.213115
# 1    102.0             0.167568             0.956757
# 2     23.0             0.735178             0.774704
# 3      1.0             0.188525             0.450820
# 4     -3.0             0.469178             0.369863
# ..     ...                  ...                  ...
# 601   77.0             0.624324             0.900000
# 602    NaN                  NaN                  NaN
# 603    NaN                  NaN                  NaN
# 604 -117.0             0.000000             0.002375
# 605  -18.0             0.921622             0.486486
#
# [606 rows x 19 columns]

# %%
fb2020 = pd.read_csv("fastball_stuff2020.csv")
fb2020['Name'] = fb2020[' first_name'] + ' ' + fb2020['last_name']
fb2020.drop(["player_id", "Unnamed: 7", "last_name", " first_name", "year"], axis=1, inplace=True)

position = fb2020.pop("Name")
fb2020.insert(0,'Name',position)
fb2020.rename(columns={"n_fastball_formatted": "Fastball %"}, inplace=True)

fb2020.sort_values("fastball_avg_spin", inplace=True, ascending=False)

fb2020.head()
# Out:
#                Name  Fastball %  fastball_avg_speed  fastball_avg_spin
# 117    Trevor Bauer        67.5                91.0               2817
# 445   Corbin Burnes        67.0                94.7               2793
# 259      Lucas Sims        48.1                93.9               2748
# 157      Jason Adam        53.5                94.8               2722
# 63       Yu Darvish        63.8                90.1               2698

# %%
fb2021 = pd.read_csv("fastball_stuff2021.csv")
fb2021['Name'] = fb2021[' first_name'] + ' ' + fb2021['last_name']
fb2021.drop(["player_id", "Unnamed: 7", "last_name", " first_name", "year"], axis=1, inplace=True)

position = fb2021.pop("Name")
fb2021.insert(0,'Name',position)
fb2021.rename(columns={"n_fastball_formatted": "Fastball %"}, inplace=True)

fb2021.sort_values("fastball_avg_spin", inplace=True, ascending=False)

fb2021.head()
# Out:
#                Name  Fastball %  fastball_avg_speed  fastball_avg_spin
# 126    Trevor Bauer        67.6                91.2               2792
# 600   Corbin Burnes        62.9                95.5               2734
# 20      Daniel Bard        48.5                97.4               2687
# 350    Tejay Antone        32.1                96.8               2677
# 232   Dillon Maples        51.7                95.2               2641

# %%
fbboth = fb2020.merge(fb2021, on="Name", how="inner", suffixes=('_2020','_2021'))
fbboth["Fastball Spin Diff (%)"] = ((fbboth["fastball_avg_spin_2021"] - fbboth["fastball_avg_spin_2020"]) / (fbboth["fastball_avg_spin_2020"])) * 100
fbboth.sort_values("Fastball Spin Diff (%)", inplace=True)
fbboth.set_index("Name", inplace=True)
fbboth.head()
# Out:
#                  Fastball %_2020  fastball_avg_speed_2020  \
# Name
#  Brett Anderson             54.5                     89.2
#  Tarik Skubal               60.1                     94.4
#  Taylor Widener             65.1                     94.5
#  Junior Guerra              60.6                     94.0
#  Cody Ponce                 68.3                     91.9
#
#                  fastball_avg_spin_2020  Fastball %_2021  \
# Name
#  Brett Anderson                    2015             53.8
#  Tarik Skubal                      2422             56.0
#  Taylor Widener                    2396             66.5
#  Junior Guerra                     2446             56.0
#  Cody Ponce                        2529             61.0
#
#                  fastball_avg_speed_2021  fastball_avg_spin_2021  \
# Name
#  Brett Anderson                     88.6                    1759
#  Tarik Skubal                       94.4                    2152
#  Taylor Widener                     92.6                    2143
#  Junior Guerra                      92.8                    2199
#  Cody Ponce                         92.0                    2278
#
#                  Fastball Spin Diff (%)
# Name
#  Brett Anderson              -12.704715
#  Tarik Skubal                -11.147812
#  Taylor Widener              -10.559265
#  Junior Guerra               -10.098119
#  Cody Ponce                   -9.924871

# %%
fbboth["Fastball Spin Diff (%)"].mean()
# Out:
# -1.1568592946162721

# %%
# did pitchers stop using fastballs
bigdrop = fbboth[fbboth["Fastball Spin Diff (%)"] <= -5]
bigdrop["Fastball Use Diff (%)"] = (bigdrop["Fastball %_2021"] - bigdrop["Fastball %_2020"])

bigdrop.head()   # There are 38 pitchers here
# Out:
# <ipython-input-12-20a1fe8a1650>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bigdrop["Fastball Use Diff (%)"] = (bigdrop["Fastball %_2021"] - bigdrop["Fastball %_2020"])
#                  Fastball %_2020  fastball_avg_speed_2020  \
# Name
#  Brett Anderson             54.5                     89.2
#  Tarik Skubal               60.1                     94.4
#  Taylor Widener             65.1                     94.5
#  Junior Guerra              60.6                     94.0
#  Cody Ponce                 68.3                     91.9
#
#                  fastball_avg_spin_2020  Fastball %_2021  \
# Name
#  Brett Anderson                    2015             53.8
#  Tarik Skubal                      2422             56.0
#  Taylor Widener                    2396             66.5
#  Junior Guerra                     2446             56.0
#  Cody Ponce                        2529             61.0
#
#                  fastball_avg_speed_2021  fastball_avg_spin_2021  \
# Name
#  Brett Anderson                     88.6                    1759
#  Tarik Skubal                       94.4                    2152
#  Taylor Widener                     92.6                    2143
#  Junior Guerra                      92.8                    2199
#  Cody Ponce                         92.0                    2278
#
#                  Fastball Spin Diff (%)  Fastball Use Diff (%)
# Name
#  Brett Anderson              -12.704715                   -0.7
#  Tarik Skubal                -11.147812                   -4.1
#  Taylor Widener              -10.559265                    1.4
#  Junior Guerra               -10.098119                   -4.6
#  Cody Ponce                   -9.924871                   -7.3

# %%
bigdrop["Fastball Use Diff (%)"].mean()
# Out:
# -0.11052631578947357

# %% [markdown]
# ### Curveball check

# %%
curve_2020 = pd.read_csv('curves 2020.csv')
curve_2021 = pd.read_csv('curves 2021.csv')
curve_2020 = curve_2020.drop(curve_2020.columns[-1],axis=1)

# %%
curve_2021 = curve_2021.drop(curve_2021.columns[-1],axis=1)

# %%
curve_2020
# Out:
#        last_name  first_name  player_id  year  cu_avg_spin  cu_avg_break_x  \
# 0     Wainwright        Adam     425794  2020       2791.0            16.8
# 1        Greinke        Zack     425844  2020       2428.0            10.6
# 2        Sanchez      Anibal     434671  2020       2027.0             4.0
# 3           Hill        Rich     448179  2020       2848.0           -19.1
# 4         Morton     Charlie     450203  2020       2887.0            17.9
# ..           ...         ...        ...   ...          ...             ...
# 128       Burnes      Corbin     669203  2020       2963.0            11.0
# 129       Bieber       Shane     669456  2020       2352.0             9.0
# 130     Richards      Trevor     670950  2020       2038.0             3.7
# 131  Margevicius        Nick     676606  2020       2001.0            -9.5
# 132       Dobnak       Randy     677976  2020          NaN             NaN
#
#      cu_avg_break_z
# 0             -65.5
# 1             -66.6
# 2             -48.6
# 3             -65.2
# 4             -54.1
# ..              ...
# 128           -47.5
# 129           -53.6
# 130           -38.9
# 131           -67.5
# 132             NaN
#
# [133 rows x 7 columns]

# %%
curve_2021
# Out:
#       last_name  first_name  player_id  year  cu_avg_spin  cu_avg_break_x  \
# 0    Wainwright        Adam     425794  2021       2839.0            16.6
# 1       Greinke        Zack     425844  2021       2365.0            11.4
# 2       Santana       Ervin     429722  2021          NaN             NaN
# 3         Petit    Yusmeiro     433589  2021       2018.0             9.7
# 4        Jansen      Kenley     445276  2021          NaN             NaN
# ..          ...         ...        ...   ...          ...             ...
# 435    Weathers        Ryan     677960  2021          NaN             NaN
# 436      Dobnak       Randy     677976  2021          NaN             NaN
# 437        Gray      Josiah     680686  2021       2430.0             1.5
# 438       Vesia        Alex     681911  2021          NaN             NaN
# 439     Arihara       Kohei     685503  2021       2252.0            10.0
#
#      cu_avg_break_z
# 0             -66.3
# 1             -65.0
# 2               NaN
# 3             -48.8
# 4               NaN
# ..              ...
# 435             NaN
# 436             NaN
# 437           -42.1
# 438             NaN
# 439           -61.5
#
# [440 rows x 7 columns]

# %%
curves = curve_2020.merge(curve_2021,on = 'player_id',how = 'inner',suffixes = ('_2020','_2021'))
curves.columns
# Out:
# Index(['last_name_2020', ' first_name_2020', 'player_id', 'year_2020',
#        'cu_avg_spin_2020', 'cu_avg_break_x_2020', 'cu_avg_break_z_2020',
#        'last_name_2021', ' first_name_2021', 'year_2021', 'cu_avg_spin_2021',
#        'cu_avg_break_x_2021', 'cu_avg_break_z_2021'],
#       dtype='object')

# %%
alist = ['year_2020','last_name_2021',' first_name_2021','year_2021']
curves = curves.drop(alist,axis = 1)

# %%
curves['Name'] = curves[' first_name_2020'] + ' ' + curves['last_name_2020'] 
curves = curves.drop([' first_name_2020','last_name_2020'],axis = 1)

# %%
curves = curves.dropna(subset=['cu_avg_spin_2020','cu_avg_spin_2021'])

# %%
curves2020_max = curves.nlargest(10,'cu_avg_spin_2020')

# %%
from mpl_toolkits.mplot3d import Axes3D
fig = plt.figure(figsize = (12,9))
ax = Axes3D(fig)
x = curves2020_max['cu_avg_break_x_2020']
y = curves2020_max['cu_avg_break_z_2020']
z = curves2020_max['cu_avg_spin_2020']
a=curves2020_max['cu_avg_break_x_2021']
b=curves2020_max['cu_avg_break_z_2021']
c=curves2020_max['cu_avg_spin_2021']
ax.scatter(x,y,z)
ax.scatter(a,b,c)
